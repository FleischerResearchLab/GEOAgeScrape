# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
from urllib import request
URL = "https://ftp.ncbi.nlm.nih.gov/geo/series/GSE43nnn/GSE43857/matrix/GSE43857-GPL11221_series_matrix.txt.gz"
response = request.urlretrieve("https://ftp.ncbi.nlm.nih.gov/geo/series/GSE43nnn/GSE43857/matrix/GSE43857-GPL11221_series_matrix.txt.gz", "download1.txt.gz")

# %%
import os

# %%
os.system("cd /Users/winnieshe/Desktop/GEOparse")
os.system("gunzip download1.txt.gz")
# Out:
# 0

# %%
def ragged_csv(filename):
    f=open(filename)
    max_n=0
    for line in f.readlines():
        words = len(line.split('\t'))
        if words > max_n:
            max_n=words
    lines=pd.read_table(filename,sep='\t', names=range(max_n))
    return lines

# %%
ragged_csv('download1.txt')
# Out:
#                              0    \
# 0                  !Series_title
# 1          !Series_geo_accession
# 2                 !Series_status
# 3        !Series_submission_date
# 4       !Series_last_update_date
# ..                           ...
# 77              !Sample_relation
# 78  !Sample_supplementary_file_1
# 79    !series_matrix_table_begin
# 80                        ID_REF
# 81      !series_matrix_table_end
#
#                                                   1    \
# 0   Patterns of Population Epigenomic Diversity in...
# 1                                            GSE43857
# 2                               Public on Mar 05 2013
# 3                                         Jan 29 2013
# 4                                         May 29 2019
# ..                                                ...
# 77  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1085...
# 79                                                NaN
# 80                                         GSM1085191
# 81                                                NaN
#
#                                                   2    \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1085...
# 79                                                NaN
# 80                                         GSM1085192
# 81                                                NaN
#
#                                                   3    \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1085...
# 79                                                NaN
# 80                                         GSM1085193
# 81                                                NaN
#
#                                                   4    \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1085...
# 79                                                NaN
# 80                                         GSM1085194
# 81                                                NaN
#
#                                                   5    \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1085...
# 79                                                NaN
# 80                                         GSM1085195
# 81                                                NaN
#
#                                                   6    \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1085...
# 79                                                NaN
# 80                                         GSM1085196
# 81                                                NaN
#
#                                                   7    \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1085...
# 79                                                NaN
# 80                                         GSM1085197
# 81                                                NaN
#
#                                                   8    \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1085...
# 79                                                NaN
# 80                                         GSM1085198
# 81                                                NaN
#
#                                                   9    ...  \
# 0                                                 NaN  ...
# 1                                                 NaN  ...
# 2                                                 NaN  ...
# 3                                                 NaN  ...
# 4                                                 NaN  ...
# ..                                                ...  ...
# 77  BioSample: https://www.ncbi.nlm.nih.gov/biosam...  ...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1085...  ...
# 79                                                NaN  ...
# 80                                         GSM1085199  ...
# 81                                                NaN  ...
#
#                                                   811  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099771
# 81                                                NaN
#
#                                                   812  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099772
# 81                                                NaN
#
#                                                   813  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099773
# 81                                                NaN
#
#                                                   814  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099774
# 81                                                NaN
#
#                                                   815  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099775
# 81                                                NaN
#
#                                                   816  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099776
# 81                                                NaN
#
#                                                   817  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099777
# 81                                                NaN
#
#                                                   818  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099778
# 81                                                NaN
#
#                                                   819  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099779
# 81                                                NaN
#
#                                                   820
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 77  SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# 78  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2099...
# 79                                                NaN
# 80                                         GSM2099780
# 81                                                NaN
#
# [82 rows x 821 columns]

# %%
df = pd.read_table(file_content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 df = pd.read_table(file_content)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py:779, in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     764 kwds_defaults = _refine_defaults_read(
#     765     dialect,
#     766     delimiter,
#    (...)
#     775     defaults={"delimiter": "\t"},
#     776 )
#     777 kwds.update(kwds_defaults)
# --> 779 return _read(filepath_or_buffer, kwds)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/common.py:823, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     818     is_wrapped = not (
#     819         isinstance(ioargs.filepath_or_buffer, str) or ioargs.should_close
#     820     )
#     822 if "r" in ioargs.mode and not hasattr(handle, "read"):
# --> 823     raise TypeError(
#     824         "Expected file path name or file-like object, "
#     825         f"got {type(ioargs.filepath_or_buffer)} type"
#     826     )
#     828 handles.reverse()  # close the most recently added buffer first
#     829 if ioargs.should_close:
#
# TypeError: Expected file path name or file-like object, got <class 'bytes'> type

# %%
geo_file_name = "geneFile3.csv"
df = pd.read_csv(geo_file_name)
df = df.loc[df['!Series_title'] == '!Sample_characteristics_ch1']
df = df.dropna(axis=1)
df = df.transpose()

# %%
df
# Out:
#                                                                              35  \
# !Series_title                                       !Sample_characteristics_ch1
# Methionine restriction alleviates age-associate...             strain: C57BL/6J
# Unnamed: 2                                                     strain: C57BL/6J
# Unnamed: 3                                                     strain: C57BL/6J
# Unnamed: 4                                                     strain: C57BL/6J
# Unnamed: 5                                                     strain: C57BL/6J
# Unnamed: 36                                         tissue: hippocampus
# Unnamed: 37                                         tissue: hippocampus
# Unnamed: 38                                         tissue: hippocampus
# Unnamed: 39                                         tissue: hippocampus
# Unnamed: 40                                         tissue: hippocampus
# Unnamed: 41                                         tissue: hippocampus
# Unnamed: 42                                         tissue: hippocampus
# Unnamed: 43                                         tissue: hippocampus
# Unnamed: 44                                         tissue: hippocampus

# %%
# print(ageIndex)
ageList = []
totalAge = 0
for ele in ageIndex:
    ageList = []
    df2 = pd.DataFrame(df[ele]).reset_index(drop=True)
    for num in df2[ele]:
        findDay = re.findall(r'(\d+.\d+) days|(\d+.\d+) day|(\d+) days|(\d+) day|days[,:() ]*(\d+[.]?\d+)|day[,:() ]*(\d+[.]?\d+)', num)
        findYear = re.findall(r'(\d+.\d+) years|(\d+.\d+) year|(\d+.\d+) yrs|(\d+.\d+) yr|(\d+) years|(\d+) years|(\d+) yrs|(\d+) yr|yr[,:() ]*(\d+[.]?\d+)|years[,:() ]*(\d+[.]?\d+)|yrs[,:() ]*(\d+[.]?\d+)|age: (\d+)$|age:(\d+.\d+)$', num)
        findMonth = re.findall(r'(\d+.\d+) months|(\d+.\d+) month|(\d+.\d+) mths|(\d+.\d+) mth|(\d+) months|(\d+) month|(\d+) mths|(\d+) mth|(\d+)[-]*month|(\d+)[-]*months|(\d+.\d+)[-]*month|(\d+.\d+)[-]*months', num)
        findWeek = re.findall(r'(\d+.\d+) weeks|(\d+.\d+) week|(\d+) weeks|(\d+) week', num)
        findHour = re.findall(r'(\d+.\d+) hours|(\d+.\d+) hour|(\d+.\d+) hrs|(\d+.\d+)hr|(\d+) hours|(\d+) hour|(\d+) hrs|(\d+) hr', num)
        
        dayList = []
        day = 0
        if len(findDay) != 0:
            findDay_input = findDay[0]
            dayList = [x for x in findDay_input if x != '']
            dayList = [float(i) for i in dayList]
            day = dayList[0]

        dayToYear = day/365

        yearList = []
        year = 0
        if len(findYear) != 0:
            findYear_input = findYear[0]
            yearList = [x for x in findYear_input if x != '']
            yearList = [float(i) for i in yearList]
            year = yearList[0]

        monthList = []
        month = 0
        if len(findMonth) != 0:
            findMonth_input = findMonth[0]
            monthList = [x for x in findMonth_input if x != '']
            monthList = [float(i) for i in monthList]
            month = monthList[0]

        monthToYear = month/12
        

        weekList = []
        week = 0
        if len(findWeek) != 0:
            findWeek_input = findWeek[0]
            weekList = [x for x in findWeek_input if x != '']
            weekList = [float(i) for i in weekList]
            week = weekList[0]

        weekToYear = week/52.143

        hourList = []
        hour = 0
        if len(findHour) != 0:
            findHour_input = findHour[0]
            hourList = [x for x in findHour_input if x != '']
            hourList = [float(i) for i in hourList]
            hour = hourList[0]

        hourToYear = hour/8760

        totalAge = dayToYear + year + monthToYear + weekToYear + hourToYear
        
        ageList.append(totalAge)

        df3 = pd.DataFrame(ageList)

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x=0, data=df3)
plt.show()

# %%
ageList
# Out:
# [61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0,
#  61.0]

# %%
df3 = pd.DataFrame(ageList)

sns.set_theme(style="darkgrid")
sns.countplot(x=0, data=df3)
plt.show()
